# %% [markdown]
# Importing Pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/linear_data
# !mkdir linear_data
# Out:
# /content/drive/MyDrive/linear_data

# %%
# !pwd
# Out:
# /content/drive/MyDrive/linear_data

# %%
#%cd linear_data/ #changing directory

# %%
# %cp /content/Linear_train.csv /content/drive/MyDrive/linear_data
# %cp /content/Linear_test.csv /content/drive/MyDrive/linear_data

# %%
# !ls
# Out:
# Linear_test.csv  Linear_train.csv

# %%
train_path = '/content/drive/MyDrive/linear_data/Linear_train.csv'
test_path = '/content/drive/MyDrive/linear_data/Linear_test.csv'
train = pd.read_csv(train_path)
train = train.loc[1:5000, :]
train
# Out:
#       Unnamed: 0          A            B          C          D          E  \
# 1              1 -17.591800  1559.053039  12.302737 -36.351098   6.256406
# 2              2 -28.321695  1305.900952 -35.681049  -9.039358 -45.519426
# 3              3 -40.471241  1612.746996 -28.980454   2.137719 -34.767491
# 4              4 -36.525271  1852.275617 -32.744347  -1.439526 -14.061837
# 5              5  34.885763  1058.478315  -6.263864   3.885085   0.227645
# ...          ...        ...          ...        ...        ...        ...
# 4996        4996 -39.011211  1195.418359   9.919650 -40.836436   9.959244
# 4997        4997  28.810707  1354.649540  46.189613  -3.019659  16.746849
# 4998        4998 -14.073684  1802.753989 -23.694672  12.174023 -37.645892
# 4999        4999   7.351802  1476.316081  30.358301 -43.804896   9.432816
# 5000        5000  40.761022  1781.957261  -0.001666  -9.343705 -47.507047
#
#                 F          G          H            I  ...           L  \
# 1     1640.834263  12.954212 -43.333128  4833.766813  ...  997.260070
# 2     2039.003363  -0.154348  18.107957  4162.395297  ...  616.059291
# 3     2757.469393  23.857472 -48.434183  4340.953927  ...  715.537625
# 4     2138.422485  44.061988  33.336936  4099.453685  ...  629.221442
# 5     2821.030205 -24.213877  31.353311  4665.864439  ...  965.409727
# ...           ...        ...        ...          ...  ...         ...
# 4996  1743.286189  15.403643  26.733313  4784.056777  ...  723.478909
# 4997  1030.894305  37.429918 -28.848527  4915.703150  ...  734.542601
# 4998  1131.610628  13.599088 -43.743199  4630.916864  ...  777.365236
# 4999  2047.866201  37.878462   1.564744  4411.832909  ...  974.773583
# 5000  2120.755571 -46.273214 -27.983407  4999.475557  ...  960.198353
#
#               M          N          O          P          Q          R  \
# 1     -1.329145  16.022086  42.972484  -7.372877  45.550946  37.576551
# 2     -6.997085  27.846844  26.511376  19.323152 -35.807513  -5.913019
# 3    -12.441561  47.883435  36.994884  30.783992  22.162383  16.465836
# 4     10.992360 -47.143335  -8.296962  -8.086565  39.169726 -49.540056
# 5    -23.328953   6.595316 -48.589973 -35.714386 -16.365606 -31.338399
# ...         ...        ...        ...        ...        ...        ...
# 4996 -42.954204 -20.304275  31.816926 -14.082286   5.134627  35.963174
# 4997  46.694191  47.114811  24.799642   2.643679   7.504306 -37.032763
# 4996  -8.051220   2.770337  13.271391  21.589720  39.323116  10.707522
# 4997 -30.273013  32.497860 -46.374748 -38.377380 -41.859788  -0.869073
# 4998   3.144188   7.753154  30.301357 -22.462982  14.972925  41.970144
# 4999  37.176606  15.897279 -25.085839 -32.474378   5.764572 -17.379347
# 5000  12.392535  -6.620254  -9.709232 -43.384826 -14.477989 -29.135059
#
#               S          T         label
# 1     21.484409 -24.206545   6484.664510
# 2    -49.592176  36.688611   2393.818082
# 3    -49.048652 -34.048583  -9397.072355
# 4     26.828040 -22.476663  10487.323575
# 5     49.129240 -41.120552   3256.252062
# ...         ...        ...           ...
# 4996 -33.652714   8.403911   2460.825677
# 4997 -23.804113  -3.269946  -3608.387356
# 4998  -6.867635  -8.731712   -319.655943
# 4999  24.388937  -9.384076  -1413.000458
# 5000  -0.140448  -4.981302  -2570.555723
#
# [5000 rows x 22 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def normal_eq(X,y):
  inv = np.linalg.inv(np.dot(X.T ,X))
  theta = np.dot(np.dot(inv, X.T), y)
  probability = np.dot(X, theta)

# normal eq => theta =inverse of (Xtranspose.X).(Xtranspose.y)

# %%
train_Y = train.loc[:,'label']
train_Y = train_Y.to_numpy()
train_Y
# Out:
# array([ 6393.11234169,  2601.04622323, 13572.11810645, ...,
#        -2147.46988819,  -344.60041085,  2972.6103187 ])

# %%
train_X = train.iloc[:, 1:21]
train_X = train_X.to_numpy()
train_X
# Out:
# array([[-1.75918001e+01,  1.55905304e+03,  1.23027370e+01, ...,
#          3.75765514e+01,  1.29265514e+01, -3.25658440e+01],
#        [-2.83216949e+01,  1.30590095e+03, -3.56810492e+01, ...,
#         -5.91301909e+00,  1.50467787e+01, -3.43323575e+01],
#        [-4.04712411e+01,  1.61274700e+03, -2.89804543e+01, ...,
#          1.64658356e+01,  4.14354251e+01,  3.35612333e+01],
#        ...,
#        [-1.40736837e+01,  1.80275399e+03, -2.36946716e+01, ...,
#         -1.90279404e+01, -2.29900897e+01, -2.30571856e+01],
#        [ 7.35180166e+00,  1.47631608e+03,  3.03583009e+01, ...,
#          2.81509116e+01,  3.17434362e+01,  1.84895621e+01],
#        [ 4.07610217e+01,  1.78195726e+03, -1.66560480e-03, ...,
#         -4.46165669e+01,  3.19306515e+01,  2.85328322e+01]])

# %%
normal_eq(y= train_Y, X= train_X)

# %%
u = np.ones([np.shape(train_X)[0], 1])
train_X = np.concatenate((u, train_X), axis = 1)
print(np.shape(train_X))
train_Y
# Out:
# (5000, 21)
# array([ 6393.11234169,  2601.04622323, 13572.11810645, ...,
#        -2147.46988819,  -344.60041085,  2972.6103187 ])

# %%
def grad(X, Y, learningrate, itrn):
  m = Y.size # training set length

  theta = np.zeros( (X.shape[1] , 1) ) # initializing theta

  cost_all = [] # to store cost Function

  # mean normalization

  for i in range( 1, X.shape[1] ):

     mean = np.mean( X[:,i])

     deviate = ( np.amax( X[:,i] ) - np.amin( X[:,i]))

     for j in range(X.shape[0]):

       X[j,i] = ( X[j,i] - mean ) / deviate


  for k in range (Y.size):

    Y[k] =  ( Y[k] - np.mean( Y ) ) / ( np.amax( Y ) - np.amin( Y ))
  

  for z in range(itrn): 

   

      y_probability = np.dot(X, theta) # hypothesis

      cost = (1/(2*m))* np.sum(np.square(y_probability - Y)) # Cost Function

      dif = (1/m)* np.sum(np.dot(X.T, (y_probability - Y) )) # differentiating Cost Function w.r.t Theta

      theta = theta - learningrate*dif # updating theta

      cost_all.append(cost) # updating cost Function list


      # to see if cost is decreasing

      if z % 100 == 0:
        print("Cost is", cost)

  return theta , cost_all

# %%
itrn = 1000 #no of interation 
learningrate = 0.000001
theta, cost_all = grad(Y =train_Y ,X = train_X, learningrate = learningrate, itrn = itrn)
# Out:
# Cost is 68.19948174751434
# Cost is 67.54912839578324
# Cost is 67.50256300107972
# Cost is 67.49922891203713
# Cost is 67.49899019077584
# Cost is 67.4989730982989
# Cost is 67.49897187447505
# Cost is 67.49897178684883
# Cost is 67.4989717805752
# Cost is 67.49897178012583

# %%
rng = np.arange(0, itrn)
plt.plot(rng, cost_all)
plt.show()

# %%
test
# Out:
#       Unnamed: 0          A            B          C          D          E  \
# 1              1  47.968749  1498.588679  24.922821 -38.979082  16.405452
# 2              2   9.762564  1316.354415   1.170771  10.365178 -11.993156
# 3              3   6.414629  1895.586749  44.496934 -49.677800 -24.825833
# 4              4  -4.112012  1130.920162  19.103960  -8.741503 -28.589701
# 5              5  -6.587367  1448.971913  42.085844  47.752786  27.959004
# ...          ...        ...          ...        ...        ...        ...
# 4996        4996 -29.976522  1420.929059 -49.667359  26.965165 -27.175763
# 4997        4997 -20.469123  1380.549779   8.584417  42.501268   3.129808
# 4998        4998  14.835699  1033.224602  38.977136  -9.316215 -22.098728
# 4999        4999  39.215735  1807.842550  33.545209  23.667546   0.134474
# 5000        5000  42.918948  1435.841283   1.563008  -1.145144 -20.863649
#
#                 F          G          H            I  ...           L  \
# 1     1798.950305 -23.660484 -34.792328  4076.982013  ...  737.135391
# 2     2714.382200  26.382837  27.442924  4178.719984  ...  940.732329
# 3     2327.316373   1.406644  44.103008  4586.697737  ...  925.441952
# 4     1299.418975  42.946135   4.758032  4809.536369  ...  797.953813
# 5     2057.316947  36.836140 -10.581332  4924.476355  ...  514.338329
# ...           ...        ...        ...          ...  ...         ...
# 4996  1102.007186 -27.267370  -0.913309  4575.785179  ...  521.765828
# 4997  1680.244629 -21.694631  22.534548  4599.148978  ...  802.783348
# 4998  1049.553264  38.198782 -25.027996  4591.603759  ...  761.004002
# 4999  1700.725129   4.741157  15.428219  4071.069513  ...  893.786383
# 5000  2801.292613 -27.653539 -44.862265  4746.622597  ...  597.187608
#
#               M          N          O          P          Q          R  \
# 1    -17.860346  42.274026 -19.886483  16.337922   9.025313  27.760845
# 2    -35.879432  23.837924   3.729191  33.564390  12.848880 -45.837834
# 3    -19.409771  25.346975  -7.729920 -42.813516 -17.666168  35.506064
# 4    -46.788081  43.876292  34.009303  34.061089 -30.182903 -41.188733
# 5     35.567851   6.639062 -37.951652  24.082068  25.488540 -49.372828
# ...         ...        ...        ...        ...        ...        ...
# 4996  -8.051220   2.770337  13.271391  21.589720  39.323116  10.707522
# 4997 -30.273013  32.497860 -46.374748 -38.377380 -41.859788  -0.869073
# 4998   3.144188   7.753154  30.301357 -22.462982  14.972925  41.970144
# 4999  37.176606  15.897279 -25.085839 -32.474378   5.764572 -17.379347
# 5000  12.392535  -6.620254  -9.709232 -43.384826 -14.477989 -29.135059
#
#               S          T         label
# 1     21.484409 -24.206545   6484.664510
# 2    -49.592176  36.688611   2393.818082
# 3    -49.048652 -34.048583  -9397.072355
# 4     26.828040 -22.476663  10487.323575
# 5     49.129240 -41.120552   3256.252062
# ...         ...        ...           ...
# 4996 -33.652714   8.403911   2460.825677
# 4997 -23.804113  -3.269946  -3608.387356
# 4998  -6.867635  -8.731712   -319.655943
# 4999  24.388937  -9.384076  -1413.000458
# 5000  -0.140448  -4.981302  -2570.555723
#
# [5000 rows x 22 columns]

# %%
test_Y = test.iloc[:, 21:]
test_Y = test_Y.to_numpy()
test_Y
# Out:
# array([[ 6484.66451042],
#        [ 2393.81808186],
#        [-9397.07235468],
#        ...,
#        [ -319.65594337],
#        [-1413.00045791],
#        [-2570.55572348]])

# %%
test_X = test.iloc[:, 1:21]
test_X = test_X.to_numpy()
test_X
# Out:
# array([[ 4.79687491e+01,  1.49858868e+03,  2.49228209e+01, ...,
#          2.77608448e+01,  2.14844087e+01, -2.42065447e+01],
#        [ 9.76256429e+00,  1.31635441e+03,  1.17077065e+00, ...,
#         -4.58378340e+01, -4.95921758e+01,  3.66886112e+01],
#        [ 6.41462852e+00,  1.89558675e+03,  4.44969341e+01, ...,
#          3.55060644e+01, -4.90486522e+01, -3.40485831e+01],
#        ...,
#        [ 1.48356986e+01,  1.03322460e+03,  3.89771358e+01, ...,
#          4.19701441e+01, -6.86763533e+00, -8.73171171e+00],
#        [ 3.92157348e+01,  1.80784255e+03,  3.35452092e+01, ...,
#         -1.73793474e+01,  2.43889375e+01, -9.38407607e+00],
#        [ 4.29189481e+01,  1.43584128e+03,  1.56300814e+00, ...,
#         -2.91350585e+01, -1.40447634e-01, -4.98130223e+00]])

# %%
y_probability, cost_all = grad(Y= test_Y, X=test_X , learningrate=0.0003, itrn = itrn)
# Out:
# Cost is 0.01332762534404406
# Cost is 0.01322838222789558
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578
# Cost is 0.013228382227895578

# %%
rng = np.arange(0, itrn)
plt.plot(rng, cost_all)
plt.show()
